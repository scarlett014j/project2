# %%
import pandas as pd
import json
csv = "full_drinks_cleaning.csv"

# %%
glass_df = pd.read_csv(csv)
glass_df
# Out:
#                             Name   Ingredient 1        Ingredient 2  \
# 0    3-Mile Long Island Iced Tea            Gin           Light rum
# 1                       410 Gone    Peach Vodka           Coca-Cola
# 2                          50/50  Vanilla vodka       Grand Marnier
# 3                       501 Blue   Blue Curacao  Blueberry schnapps
# 4                     69 Special            Gin                7-Up
# ..                           ...            ...                 ...
# 387                       Vesper            Gin               Vodka
# 388                  Yellow Bird      White Rum            Galliano
# 389              Zippy's Revenge       Amaretto                 Rum
# 390                       Zombie            Rum            Gold rum
# 391                    Zorbatini          Vodka                Ouzo
#
#       Ingredient 3 Ingredient 4 Ingredient 5 Ingredient 6       Ingredient 7  \
# ...

# %%
#glass_df = glass_df.drop(['Unnamed: 0','Glass', 'Instructions', 'Ingredient 10', 'Ingredient 11', 'Ingredient 12', 'Ingredient 13', 'Ingredient 14', 'Ingredient 15', 'Measuremnt 10', 'Measurement 11', 'Measurement 12', 'Measurement 13', 'Measurement 14', 'Measurement 15', 'Image URL'], axis=1)
#glass_df

# %%
result = glass_df.to_json("glass.json", orient="index")

# %%
type(result)
# Out:
# str

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2fc680fab38b> in <module>
# ----> 1 result.to_json("glass.json")
#
# AttributeError: 'str' object has no attribute 'to_json'

# %%
drink_l = []
for index, row in glass_df.iterrows():
    drink_d = {"drink": []}
